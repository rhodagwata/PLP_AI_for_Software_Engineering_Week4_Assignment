# %%
# !pip install --trusted-host pypi.org --trusted-host files.pythonhosted.org selenium pytest pytest-html --break-system-packages
# Out:
# ...
#   Using cached outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# ...
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.7 MB 435.7 kB/s eta 0:00:23
#    ---------------------------------------- 0.0/9.7 MB 435.7 kB/s eta 0:00:23
#    ---------------------------------------- 0.1/9.7 MB 459.5 kB/s eta 0:00:21
#     --------------------------------------- 0.1/9.7 MB 610.6 kB/s eta 0:00:16
#     --------------------------------------- 0.2/9.7 MB 655.4 kB/s eta 0:00:15
#    - -------------------------------------- 0.3/9.7 MB 820.5 kB/s eta 0:00:12
#    - -------------------------------------- 0.4/9.7 MB 1.0 MB/s eta 0:00:10
#    - -------------------------------------- 0.5/9.7 MB 1.1 MB/s eta 0:00:09
# ...
